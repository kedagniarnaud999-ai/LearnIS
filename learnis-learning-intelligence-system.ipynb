# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/model_00000.weights.h5
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/model_00001.weights.h5
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/model_00003.weights.h5
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/image_converter.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/config.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/model_00002.weights.h5
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/preprocessor.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/model.weights.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/tokenizer.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/metadata.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/model_00005.weights.h5
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/video_converter.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/model_00004.weights.h5
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/task.json
# /kaggle/input/models/keras/gemma4/keras/gemma4_instruct_31b/2/assets/tokenizer/vocabulary.spm
# /kaggle/input/datasets/arnaudkedagni/learnis-socratic-ai-tutor/learnIS_kaggle.ipynb
